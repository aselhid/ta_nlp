# %%
a = [
   {
      "wid": "1",
      "text": "bisa",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "mampu (kuasa melakukan sesuatu); dapat",
            "enwordnet": {
               "sense": {
                  "key": "able%3:00:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "zat racun yang dapat menyebabkan luka, busuk, atau mati bagi sesuatu yang hidup (biasanya terdapat pada binatang)",
            "enwordnet": [
               {
                  "key": "poison%1:27:00::"
               },
               {
                  "key": "toxicant%1:27:00::"
               },
               {
                  "key": "poisonous_substance%1:27:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "mungkin, boleh"
         }
      ]
   },
   {
      "wid": "2",
      "text": "kaki",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "anggota badan yang menopang tubuh dan dipakai untuk berjalan (dari pangkal paha ke bawah)",
            "enwordnet": {
               "sense": {
                  "key": "foot%1:08:01"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "bagian atau suatu benda yang menjadi penopang (penyangga) yang berfungsi sebagai kaki",
            "enwordnet": [
               {
                  "key": "base%1:06:01"
               },
               {
                  "key": "foundation%1:06:00"
               },
               {
                  "key": "fundament%1:06:00"
               },
               {
                  "key": "foot%1:06:00"
               },
               {
                  "key": "groundwork%1:06:00"
               },
               {
                  "key": "substructure%1:06:00"
               },
               {
                  "key": "understructure%1:06:00"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "bagian yang bawah",
            "enwordnet": {
               "sense": {
                  "key": "foot%1:15:00"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "ukuran panjang, 12 inci (0.3048 m)",
            "enwordnet": [
               {
                  "key": "foot%1:23:00"
               },
               {
                  "key": "ft%1:23:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "3",
      "text": "kepala",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bagian tubuh yang di atas leher (pada manusia dan beberapa jenis hewan merupakan tempat otak, pusat jaringan saraf, dan beberapa pusat indra)",
            "enwordnet": {
               "sense": {
                  "key": "head%1:08:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "pemimpin; ketua (kantor, pekerjaan, perkumpulan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "head%1:18:00::"
               },
               {
                  "key": "chief%1:18:00::"
               },
               {
                  "key": "leader%1:18:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "pikiran, akal, budi",
            "enwordnet": [
               {
                  "key": "mind%1:09:00::"
               },
               {
                  "key": "head%1:09:00::"
               },
               {
                  "key": "brain%1:09:01::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "bagian suatu benda yang sebelah atas (ujung, depan, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "head%1:15:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "4",
      "text": "halaman",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "pekarangan rumah (sekolah dan sebagainya); tanah di sekitar rumah (sekolah dan sebagainya)",
            "context": [],
            "enwordnet": [
               {
                  "key": "yard%1:06:02::"
               },
               {
                  "key": "grounds%1:06:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "muka dari lembaran buku (majalah, surat kabar, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "page%1:10:00"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "tampilan muka di perangkat elektronik atau yang tersambung ke internet"
         }
      ]
   },
   {
      "wid": "5",
      "text": "buah",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bagian tumbuhan yang berasal dari bunga atau putik",
            "enwordnet": {
               "sense": {
                  "key": "fruit%1:20:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "kata penggolong bermacam-macam benda"
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sesuatu yang diadakan (dibuat, diakibatkan) oleh suatu kejadian",
            "enwordnet": {
               "sense": {
                  "key": "fruit%1:11:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "6",
      "text": "bunga",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bagian tumbuhan yg akan menjadi buah, biasanya elok warnanya dan harum baunya",
            "enwordnet": [
               {
                  "key": "flower%1:20:02::"
               },
               {
                  "key": "bloom%1:20:00::"
               },
               {
                  "key": "blossom%1:20:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "imbalan jasa untuk penggunaan uang atau modal yang dibayar pada waktu yang disetujui, umumnya dinyatakan sebagai persentase dari modal pokok",
            "enwordnet": [
               {
                  "key": "fixed_charge%1:21:00::"
               },
               {
                  "key": "interest%1:21:00::"
               },
               {
                  "key": "due%1:21:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sesuatu yang indah (bermakna konotatif)"
         }
      ]
   },
   {
      "wid": "7",
      "text": "bintang",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "benda langit terdiri atas gas menyala seperti matahari, terutama tampak pada malam hari",
            "enwordnet": {
               "sense": {
                  "key": "star%1:17:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "orang yang terkemuka atau terbaik",
            "enwordnet": {
               "sense": {
                  "key": "star%1:18:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sesuatu berbentuk bintang",
            "enwordnet": {
               "sense": {
                  "key": "star%1:25:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "8",
      "text": "bulan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "benda langit yang mengitari bumi, bersinar pada malam hari karena pantulan sinar matahari",
            "enwordnet": {
               "sense": {
                  "key": "moon%1:17:01::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "masa atau jangka waktu perputaran bulan mengitari bumi dari mulai tampaknya bulan sampai hilang kembali (29 atau 30 hari)",
            "enwordnet": {
               "sense": {
                  "key": "month%1:28:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "seperdua belas bagian dari tahun kalender",
            "enwordnet": [
               {
                  "key": "month%1:28:01::"
               },
               {
                  "key": "calendar_month%1:28:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "satelit planet",
            "enwordnet": {
               "sense": {
                  "key": "moon%1:17:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "9",
      "text": "jam",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "alat untuk mengukur waktu (seperti arloji, lonceng dinding)",
            "enwordnet": {
               "sense": {
                  "key": "clock%1:06:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "waktu yang lamanya 1/24 hari (dari sehari semalam) sama dengan 60 menit atau 3.600 detik",
            "enwordnet": {
               "sense": {
                  "key": "hour%1:28:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "pukul",
            "enwordnet": {
               "sense": {
                  "key": "o'clock%4:02:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "waktu; saat",
            "enwordnet": {
               "sense": {
                  "key": "time%1:28:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "10",
      "text": "mata",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "indra untuk melihat; indra penglihat",
            "enwordnet": [
               {
                  "key": "eye%1:08:00::"
               },
               {
                  "key": "oculus%1:08:00"
               },
               {
                  "key": "optic%1:08:00"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "yang terpenting (sumbu, pokok, sumber, dan sebagainya)"
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "unit, tipe, satuan",
            "enwordnet": {
               "sense": {
                  "key": "unit%1:23:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "bagian yang tajam pada alat pemotong (pada pisau, kapak, dan sebagainya)"
         },
         {
            "sid": "5",
            "pos": "noun",
            "gloss": "sesuatu yang menyerupai mata (seperti lubang kecil)",
            "enwordnet": {
               "sense": {
                  "key": "eye%1:06:00::"
               }
            }
         },
         {
            "sid": "6",
            "pos": "noun",
            "gloss": "pandangan; pengamatan; penilaian"
         }
      ]
   },
   {
      "wid": "11",
      "text": "kali",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "kata untuk menyatakan kekerapan tindakan",
            "enwordnet": {
               "sense": {
                  "key": "time%1:11:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "kata untuk menyatakan kelipatan, perbanyakan, pergandaan, atau perbandingan (angka, ukuran, harga, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "time%1:04:00::"
               },
               {
                  "key": "multiplication%1:04:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "batang air; bengawan; sungai; aliran air yang besar",
            "enwordnet": {
               "sense": {
                  "key": "river%1:17:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "kata untuk menyatakan salah satu waktu terjadinya peristiwa yang merupakan bagian dari rangkaian peristiwa yang pernah dan masih akan terus terjadi",
            "enwordnet": {
               "sense": {
                  "key": "times%1:28:01::"
               }
            }
         }
      ]
   },
   {
      "wid": "12",
      "text": "sarung",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "pembungkus; pelindung",
            "enwordnet": [
               {
                  "key": "binding%1:06:00::"
               },
               {
                  "key": "cover%1:06:04::"
               },
               {
                  "key": "case%1:06:02::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "kain sarung",
            "enwordnet": {
               "sense": {
                  "key": "sarong%1:06:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "13",
      "text": "dunia",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bumi dengan segala sesuatu yang terdapat di atasnya; planet tempat kita hidup",
            "enwordnet": {
               "sense": {
                  "key": "world%1:17:01::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "lingkungan atau lapangan kehidupan",
            "enwordnet": {
               "sense": {
                  "key": "world%1:17:02::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "semua manusia yang ada di muka bumi",
            "enwordnet": [
               {
                  "key": "world%1:05:00::"
               },
               {
                  "key": "humankind%1:05:00::"
               },
               {
                  "key": "human_beings%1:05:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "sesuatu yang bersifat kebendaan, fana, tidak kekal",
            "enwordnet": [
               {
                  "key": "world%1:09:01::"
               },
               {
                  "key": "earth%1:09:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "14",
      "text": "badan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "tubuh (jasad manusia keseluruhan); jasmani; raga",
            "enwordnet": {
               "sense": {
                  "key": "body%1:08:01::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "bagian utama dari suatu benda",
            "enwordnet": {
               "sense": {
                  "key": "body%1:06:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sekumpulan orang yang merupakan kesatuan untuk mengerjakan sesuatu",
            "enwordnet": {
               "sense": {
                  "key": "body%1:14:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "15",
      "text": "nilai",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "harga, nilai ekonomis",
            "enwordnet": {
               "sense": {
                  "key": "value%1:21:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "kuantitas numerik (angka atau huruf ) yang menyatakan pencapaian",
            "enwordnet": [
               {
                  "key": "mark%1:09:01::"
               },
               {
                  "key": "grade%1:09:00::"
               },
               {
                  "key": "score%1:09:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sifat-sifat (hal-hal) yang penting atau berguna bagi kemanusiaan",
            "enwordnet": {
               "sense": {
                  "key": "value%1:09:01::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "skala, intensitas, atau angka yang menjadi atribut sesuatu; banyak sedikitnya isi; berapa banyaknya sesuatu dapat diukur",
            "enwordnet": {
               "sense": {
                  "key": "value%1:09:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "16",
      "text": "layar",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "kain tebal yang dibentangkan untuk menadah angin agar perahu (kapal) dapat berjalan (laju)",
            "enwordnet": {
               "sense": {
                  "key": "sail%1:06:00"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "bidang (berupa kain, papan, kaca) tempat menayangkan gambar (film, televisi, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "screen%1:06:05"
               }
            }
         }
      ]
   },
   {
      "wid": "17",
      "text": "kulit",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "pemalut paling luar tubuh (manusia, binatang); jangat",
            "enwordnet": [
               {
                  "key": "skin%1:08:00::"
               },
               {
                  "key": "tegument%1:08:00::"
               },
               {
                  "key": "skin%1:05:01::"
               },
               {
                  "key": "pelt%1:05:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "hasil olahan kulit binatang (disamak, dikeringkan, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "leather%1:27:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "lapisan terluar; pemalut inti, memiliki isi di dalamnya (buah, biji, kayu, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "skin%1:13:00::"
               },
               {
                  "key": "peel%1:13:00::"
               },
               {
                  "key": "skin%1:06:01::"
               }
            ]
         }
      ]
   },
   {
      "wid": "18",
      "text": "bidang",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "permukaan rata dan tentu batasnya, permukaan yang dibatasi panjang dan lebar",
            "enwordnet": [
               {
                  "key": "side%1:06:00::"
               },
               {
                  "key": "plane%1:25:00::"
               },
               {
                  "key": "sheet%1:25:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "lapangan, aspek (dalam arti lingkungan pekerjaan, pengetahuan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "discipline%1:09:00::"
               },
               {
                  "key": "subject%1:09:00::"
               },
               {
                  "key": "field%1:09:00::"
               },
               {
                  "key": "area%1:09:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "kata penggolong bagi objek yang luas seperti tanah, sawah, ladang"
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "lebar",
            "enwordnet": [
               {
                  "key": "wide%3:00:00:large:00"
               },
               {
                  "key": "broad%3:00:00:large:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "19",
      "text": "jalan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "tempat untuk lalu lintas orang (kendaraan dan sebagainya); perlintasan; akses",
            "enwordnet": [
               {
                  "key": "road%1:06:00::"
               },
               {
                  "key": "route%1:06:00::"
               },
               {
                  "key": "street%1:06:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "akses, penghubung",
            "enword": {
               "sense": {
                  "key": "way%1:06:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "perkembangan atau berlangsungnya (tentang perundingan, rapat, cerita, dan sebagainya) dari awal sampai akhir",
            "enwordnet": [
               {
                  "key": "way%1:07:01::"
               },
               {
                  "key": "manner%1:07:02::"
               },
               {
                  "key": "style%1:07:00::"
               },
               {
                  "key": "mode%1:07:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "cara (akal, syarat, ikhtiar, dan sebagainya) untuk melakukan (mengerjakan, mencapai, mencari) sesuatu",
            "enwordnet": [
               {
                  "key": "means%1:04:00::"
               },
               {
                  "key": "way%1:04:01::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "noun",
            "gloss": "kesempatan (untuk mengerjakan sesuatu)",
            "enwordnet": [
               {
                  "key": "opportunity%1:26:00::"
               },
               {
                  "key": "chance%1:26:00::"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "noun",
            "gloss": "panduan perilaku dan tindak-tanduk, jalan kehidupan",
            "enwordnet": [
               {
                  "key": "way%1:04:00::"
               },
               {
                  "key": "path%1:04:00::"
               },
               {
                  "key": "way_of_life%1:04:00::"
               }
            ]
         },
         {
            "sid": "7",
            "pos": "verb",
            "gloss": "melangkahkan kaki",
            "enwordnet": {
               "sense": {
                  "key": "walk%2:38:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "20",
      "text": "memerah",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "menjadi merah",
            "ewordnet": [
               {
                  "key": "redden%2:29:00::"
               },
               {
                  "key": "blush%2:29:00::"
               },
               {
                  "key": "crimson%2:29:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "memeras (memijit) supaya keluar airnya",
            "ewordnet": {
               "sense": {
                  "key": "squeeze%2:35:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "21",
      "text": "menurunkan",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "membawa (menjadikan) sesuatu turun, seperti menarik turun, mengerek ke bawah, dan sebagainya; menyebabkan seseorang ke posisi lebih rendah",
            "enwordnet": [
               {
                  "key": "take_down%2:38:00::"
               },
               {
                  "key": "let_down%2:38:00::"
               },
               {
                  "key": "get_down%2:38:00::"
               },
               {
                  "key": "bring_down%2:38:00::"
               },
               {
                  "key": "lower%2:38:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "merendahkan (derajat, kedudukan, dan sebagainya); memerosotkan atau mengurangkan (harga, nilai, dan sebagainya); menyurutkan (menyusutkan)",
            "enwordnet": [
               {
                  "key": "decrease%2:30:00::"
               },
               {
                  "key": "diminish%2:30:00::"
               },
               {
                  "key": "lessen%2:30:00::"
               },
               {
                  "key": "degrade%2:30:00::"
               },
               {
                  "key": "cheapen%2:30:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "menyampaikan sesuatu, seperti wahyu (sabda, ajaran, dan sebagainya)"
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "memilih untuk ikut bermain (bertandang dan sebagainya); menyertakan; mengikutkan",
            "enwordnet": {
               "sense": {
                  "key": "field%2:31:00::"
               }
            }
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "memperanakkan; meninggalkan (warisan, pusaka, dan sebagainya) kepada; memindahkan kepada (anak, cucu, dan sebagainya)"
         },
         {
            "sid": "6",
            "pos": "verb",
            "gloss": "menyederhanakan bentuk, seperti persamaan",
            "enwordnet": {
               "sense": {
                  "key": "reduce%2:40:04::"
               }
            }
         }
      ]
   },
   {
      "wid": "22",
      "text": "mengikat",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "mengebat; mengeratkan (menyatukan dan sebagainya) dengan tali",
            "enwordnet": [
               {
                  "key": "tie%2:35:00::"
               },
               {
                  "key": "bind%2:35:01::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "membuat ikatan sosial atau emosional",
            "enwordnet": [
               {
                  "key": "bind%2:41:01::"
               },
               {
                  "key": "tie%2:41:01::"
               },
               {
                  "key": "attach%2:41:03::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "wajib ditepati",
            "enwordnet": {
               "sense": {
                  "key": "binding%3:00:00:valid:00"
               }
            }
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "membentuk ikatan (kimia)",
            "enwordnet": {
               "sense": {
                  "key": "bind%2:30:09::"
               }
            }
         }
      ]
   },
   {
      "wid": "23",
      "text": "mengandung",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "tercantum di dalamnya; memuat; berisi",
            "enwordnet": [
               {
                  "key": "contain%2:42:13::"
               },
               {
                  "key": "hold%2:42:13::"
               },
               {
                  "key": "carry%2:42:03::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "hamil; membawa keturunan yang sedang berkembang di dalam badan",
            "enwordnet": [
               {
                  "key": "carry%2:29:00::"
               },
               {
                  "key": "bear%2:29:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "24",
      "text": "menyusun",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "menempatkan secara beraturan",
            "enwordnet": [
               {
                  "key": "arrange%2:35:00::"
               },
               {
                  "key": "set up%2:35:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "merencanakan, menyiapkan, membentuk",
            "enwordnet": [
               {
                  "key": "arrange%2:36:03::"
               },
               {
                  "key": "stage%2:36:01::"
               },
               {
                  "key": "plan%2:36:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "membuat atau mengarang (kamus, ensiklopedia, puisi, lagu, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "compose%2:36:01::"
               }
            }
         }
      ]
   },
   {
      "wid": "25",
      "text": "memecahkan",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "merusakkan hingga pecah",
            "enwordnet": {
               "sense": {
                  "key": "break%2:30:10::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mengatasi; menyelesaikan",
            "enwordnet": [
               {
                  "key": "solve%2:31:00::"
               },
               {
                  "key": "figure_out%2:31:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "mengungguli (prestasi yang ada sebelumnya)",
            "enwordnet": [
               {
                  "key": "break%2:33:00::"
               },
               {
                  "key": "better%2:33:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "memekakkan; memusingkan"
         }
      ]
   },
   {
      "wid": "26",
      "text": "mendorong",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "memindahkan dengan tenaga; menolak dari bagian belakang atau bagian depan",
            "enwordnet": {
               "sense": {
                  "key": "push%2:38:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mendesak atau memaksa supaya berbuat sesuatu",
            "enwordnet": [
               {
                  "key": "push%2:32:01::"
               },
               {
                  "key": "urge%2:32:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "27",
      "text": "menjaga",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "mempertahankan agar kondisi, posisi, atau aktivitas tetap berjalan",
            "enwordnet": [
               {
                  "key": "keep%2:42:00::"
               },
               {
                  "key": "maintain%2:42:00::"
               },
               {
                  "key": "hold%2:42:00::"
               },
               {
                  "key": "preserve%2:42:00::"
               },
               {
                  "key": "carry_on%2:42:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mengiringi untuk melindungi dari bahaya; mengawal",
            "enwordnet": [
               {
                  "key": "guard%2:33:00"
               },
               {
                  "key": "ward%2:33:00"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "menjadi penjaga; bertanggung jawab mengurus",
            "enwordnet": {
               "sense": {
                  "key": "keep%2:40:01::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "merawat dan mempertahankan agar tidak rusak atau hancur",
            "enwordnet": [
               {
                  "key": "keep_up%2:40:00::"
               },
               {
                  "key": "maintain%2:40:00::"
               },
               {
                  "key": "conserve%2:40:00::"
               },
               {
                  "key": "preserve%2:40:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "28",
      "text": "mengejar",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "menyusul dengan berlari; memburu",
            "enwordnet": [
               {
                  "key": "chase%2:38:00::"
               },
               {
                  "key": "trail%2:38:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "berusaha keras hendak mencapai (mendapatkan dan sebagainya); menginginkan dengan sungguh-sungguh",
            "enwordnet": [
               {
                  "key": "pursue%2:35:00::"
               },
               {
                  "key": "go_after%2:35:00::"
               },
               {
                  "key": "quest_for%2:35:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "29",
      "text": "mengeluarkan",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "membawa (menyebabkan dan sebagainya) keluar; memindahkan sesuatu dari sebelah dalam ke sebelah luar",
            "enwordnet": [
               {
                  "key": "draw%2:38:01::"
               },
               {
                  "key": "pull%2:38:03::"
               },
               {
                  "key": "pull_out%2:38:03::"
               },
               {
                  "key": "get_out%2:38:02::"
               },
               {
                  "key": "take_out%2:38:10::"
               },
               {
                  "key": "take_out%2:35:01::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "menghasilkan sesuatu produk konkrit atau abstrak untuk distribusi publik (misalnya menerbitkan, meluncurkan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "publish%2:32:00::"
               },
               {
                  "key": "bring_out%2:32:00::"
               },
               {
                  "key": "put_out%2:32:00::"
               },
               {
                  "key": "issue%2:32:00::"
               },
               {
                  "key": "release%2:32:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "memecat (melepas) pegawai (murid dan sebagainya); memberhentikan dari pekerjaan (sekolah, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "displace%2:41:04::"
               },
               {
                  "key": "fire%2:41:00::"
               },
               {
                  "key": "dismiss%2:41:00::"
               },
               {
                  "key": "force_out%2:41:00::"
               },
               {
                  "key": "terminate%2:41:01::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "membelanjakan",
            "enwordnet": [
               {
                  "key": "spend%2:40:00::"
               },
               {
                  "key": "expend%2:40:00::"
               },
               {
                  "key": "drop%2:40:00::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "melahirkan perasaan, pendapat, dan sebagainya; mengekspresikan sesuatu",
            "enwordnet": [
               {
                  "key": "utter%2:32:02::"
               },
               {
                  "key": "emit%2:32:00::"
               },
               {
                  "key": "let_out%2:32:02::"
               },
               {
                  "key": "let_loose%2:32:00::"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "verb",
            "gloss": "mengeluarkan substansi berupa cairan, gas, atau kandungan tertentu",
            "enwordnet": [
               {
                  "key": "exhaust%2:29:02::"
               },
               {
                  "key": "discharge%2:29:00::"
               },
               {
                  "key": "expel%2:29:00::"
               },
               {
                  "key": "eject%2:29:00::"
               },
               {
                  "key": "release%2:29:01::"
               }
            ]
         }
      ]
   },
   {
      "wid": "30",
      "text": "membawa",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "memegang atau mengangkat sesuatu sambil berjalan atau bergerak dari satu tempat ke tempat lain",
            "enwordnet": [
               {
                  "key": "carry%2:42:01::"
               },
               {
                  "key": "pack%2:42:00::"
               },
               {
                  "key": "take%2:42:10::"
               },
               {
                  "key": "bring%2:38:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mengangkut; memuat; memindahkan; mengirimkan",
            "enwordnet": [
               {
                  "key": "carry%2:35:02::"
               },
               {
                  "key": "transport%2:35:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "mengajak pergi; pergi bersama-sama",
            "enwordnet": {
               "sense": {
                  "key": "bring%2:35:02::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "menyebabkan seseorang atau sesuatu berubah ke situasi atau kondisi tertentu, melakukan aktivitas tertentu",
            "enwordnet": [
               {
                  "key": "bring%2:35:04::"
               },
               {
                  "key": "cause%2:32:00::"
               },
               {
                  "key": "lead%2:32:00::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "mendatangkan; mengakibatkan; menimbulkan sesuatu sebagai akibat",
            "enwordnet": [
               {
                  "key": "bring%2:36:00::"
               },
               {
                  "key": "make_for%2:36:00::"
               },
               {
                  "key": "wreak%2:36:00::"
               },
               {
                  "key": "cause%2:36:00::"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "verb",
            "gloss": "menarik atau melibatkan (dalam urusan, perkara, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "involve%2:42:04::"
               }
            }
         },
         {
            "sid": "7",
            "pos": "verb",
            "gloss": "menyampaikan sesuatu; menjadi alat perantara",
            "enwordnet": [
               {
                  "key": "carry%2:38:03::"
               },
               {
                  "key": "convey%2:38:02::"
               }
            ]
         }
      ]
   },
   {
      "wid": "31",
      "text": "menerima",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "mengambil sesuatu yang diberikan, dikirimkan, dan sebagainya",
            "enwordnet": {
               "sense": {
                  "key": "receive%2:40:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mendapat; memperoleh sesuatu hal yang bersifat abstrak",
            "enwordnet": [
               {
                  "key": "receive%2:30:01::"
               },
               {
                  "key": "get%2:30:03::"
               },
               {
                  "key": "obtain%2:30:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "membenarkan; menganggap tepat",
            "enwordnet": {
               "sense": {
                  "key": "accept%2:31:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "merespons; bereaksi positif",
            "enwordnet": [
               {
                  "key": "accept%2:32:00::"
               },
               {
                  "key": "consent%2:32:00::"
               },
               {
                  "key": "go_for%2:32:00::"
               },
               {
                  "key": "welcome%2:32:00::"
               },
               {
                  "key": "receive%2:32:00::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "menerima apa yang ditawarkan; mengesahkan; menyetujui (usul, anjuran, dan sebagainya); meluluskan atau mengabulkan (permintaan dan sebagainya)",
            "enwordnet": [
               {
                  "key": "accept%2:40:00::"
               },
               {
                  "key": "take%2:40:05::"
               },
               {
                  "key": "have%2:40:05::"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "verb",
            "gloss": "mengizinkan (masuk menjadi anggota, murid, pegawai, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "accept%2:40:03::"
               },
               {
                  "key": "admit%2:40:00::"
               },
               {
                  "key": "take_on%2:40:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "32",
      "text": "mengisi",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "memberi isi; memasukkan sesuatu ke dalam",
            "enwordnet": [
               {
                  "key": "fill%2:30:01::"
               },
               {
                  "key": "fill_up%2:30:00::"
               },
               {
                  "key": "load%2:35:01::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "melakukan sesuatu untuk merintang waktu; aksi selama masa tertentu",
            "enwordnet": [
               {
                  "key": "spend%2:42:00::"
               },
               {
                  "key": "pass%2:42:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "melengkapi; menambahkan sesuatu (informasi dan sebagainya)",
            "enwordnet": [
               {
                  "key": "fill_out%2:32:00::"
               },
               {
                  "key": "fill_in%%2:32:02::"
               },
               {
                  "key": "complete%%2:32:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "menempati posisi atau peran",
            "enwordnet": [
               {
                  "key": "fill%2:41:00::"
               },
               {
                  "key": "take%2:41:00::"
               },
               {
                  "key": "occupy%2:41:04::"
               }
            ]
         }
      ]
   },
   {
      "wid": "33",
      "text": "menangkap",
      "senses": [
         {
            "sid": "1",
            "pos": "verb",
            "gloss": "memegang sesuatu yg bergerak (misalnya barang yang dilemparkan); memegang dengan tangan atau dengan alat",
            "enwordnet": [
               {
                  "key": "catch%2:35:00::"
               },
               {
                  "key": "grab%2:35:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "verb",
            "gloss": "mendapatkan sesuatu setelah pengejaran, perburuan, dsb (binatang, penjahat, dsb)",
            "enwordnet": [
               {
                  "key": "catch%2:35:01::"
               },
               {
                  "key": "capture%2:35:01::"
               },
               {
                  "key": "get%2:35:09::"
               },
               {
                  "key": "catch%2:35:03::"
               },
               {
                  "key": "capture%2:35:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "mendapati, menemukan secara tidak sengaja (orang berbuat jahat, kesalahan, rahasia, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "catch%2:31:01::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "verb",
            "gloss": "berhasil merepresentasikan atau mengekspresikan (suara, siaran radio, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "capture%2:36:00::"
               }
            }
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "dapat memahami; mencerap maksud",
            "enwordnet": [
               {
                  "key": "understand%2:31:00::"
               },
               {
                  "key": "catch%2:31:03::"
               },
               {
                  "key": "get%2:31:09::"
               }
            ]
         }
      ]
   },
   {
      "wid": "34",
      "text": "lingkungan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "semua yang memengaruhi pertumbuhan makhluk hidup",
            "enwordnet": [
               {
                  "key": "environment%1:15:00::"
               },
               {
                  "key": "surrounding%1:15:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "daerah (kawasan dan sebagainya) yang termasuk di dalamnya",
            "enwordnet": {
               "sense": {
                  "key": "neighboorhood%1:15:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "golongan; kalangan; kumpulan orang",
            "enwordnet": {
               "sense": {
                  "key": "circle%1:14:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "35",
      "text": "harapan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "sesuatu yang (dapat) diharapkan, mungkin terjadi",
            "enwordnet": [
               {
                  "key": "chance%1:26:00::"
               },
               {
                  "key": "possibility%1:26:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "keinginan supaya menjadi kenyataan",
            "enwordnet": [
               {
                  "key": "hope%1:12:00::"
               },
               {
                  "key": "wish%1:12:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "orang atau sesuatu yang diharapkan atau dipercaya; tumpuan",
            "enwordnet": {
               "sense": {
                  "key": "hope%1:18:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "36",
      "text": "jaringan",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "susunan sel-sel khusus yang sama pada tubuh dan bersatu dalam menjalankan fungsi biologis tertentu",
            "enwordnet": {
               "sense": {
                  "key": "tissue%1:08:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "sekelompok komputer atau perangkat terkait yang dihubungkan dengan fasilitas komunikasi",
            "enwordnet": {
               "sense": {
                  "key": "network%1:06:01::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "sistem yang menghubungkan orang atau sesuatu",
            "enwordnet": [
               {
                  "key": "network%1:14:00::"
               },
               {
                  "key": "web%1:14:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "37",
      "text": "pembagian",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "proses, cara, perbuatan membagi menjadi beberapa bagian terpisah; memisahkan dengan membuat suatu batas",
            "enwordnet": [
               {
                  "key": "division%1:04:02::"
               },
               {
                  "key": "partition%1:04:00::"
               },
               {
                  "key": "partitioning%1:04:00::"
               },
               {
                  "key": "segmentation%1:04:00::"
               },
               {
                  "key": "sectionalization%1:04:00::"
               },
               {
                  "key": "sectionalisation%1:04:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "proses, cara, perbuatan melakukan hitungan membagi",
            "enwordnet": {
               "sense": {
                  "key": "division%1:04:01::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "proses, cara, perbuatan mengelompokkan ke dalam kategori-kategori tertentu",
            "enwordnet": [
               {
                  "key": "classification%1:14:00::"
               },
               {
                  "key": "categorization%1:14:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "proses, cara, perbuatan mengalokasikan sesuai rencana tertentu",
            "enwordnet": [
               {
                  "key": "allotment%1:04:00::"
               },
               {
                  "key": "apportionment%1:04:00::"
               },
               {
                  "key": "apportioning%1:04:00::"
               },
               {
                  "key": "allocation%1:04:00::"
               },
               {
                  "key": "assignation%1:04:01::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "noun",
            "gloss": "proses, cara, perbuatan mendistribusikan atau menyebarkan sehingga sesuatu terbagi ke pihak yang memperoleh pembagian",
            "enwordnet": {
               "sense": {
                  "key": "distribution%1:04:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "38",
      "text": "kabur",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "samar, berkabut, tidak jelas terkait penglihatan",
            "enwordnet": [
               {
                  "key": "hazy%3:00:00:indistinct:00"
               },
               {
                  "key": "fuzzy%3:00:00:indistinct:00"
               },
               {
                  "key": "vague%3:00:00:indistinct:00"
               },
               {
                  "key": "blurred%3:00:00:indistinct:00"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "tidak jelas diekspresikan, tidak dapat dipahami dengan baik",
            "enwordnet": [
               {
                  "key": "vague%3:00:00:unclear:00"
               },
               {
                  "key": "obscure%3:00:00:unclear:00"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "verb",
            "gloss": "berlari cepat-cepat; melarikan diri; meninggalkan tugas (pekerjaan, keluarga, dan sebagainya) tanpa pamit; menghilang",
            "enwordnet": [
               {
                  "key": "run_away%2:38:00::"
               },
               {
                  "key": "escape%2:38:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "39",
      "text": "baru",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "belum lama (dibeli, dimiliki, dipakai); baru saja selesai dibuat atau ditemukan; baru dimulai",
            "enwordnet": {
               "sense": {
                  "key": "new%3:00:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "adverb",
            "gloss": "belum lama antaranya; baru saja",
            "enwordnet": [
               {
                  "key": "new%4:02:00::"
               },
               {
                  "key": "newly%4:02:00::"
               },
               {
                  "key": "fresh%4:02:00::"
               },
               {
                  "key": "freshly%4:02:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adverb",
            "gloss": "kemudian; setelah itu",
            "enwordnet": [
               {
                  "key": "then%4:02:00::"
               },
               {
                  "key": "so%4:02:09::"
               }
            ]
         }
      ]
   },
   {
      "wid": "40",
      "text": "dalam",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bagian yang di dalam, bukan bagian luar",
            "enwordnet": [
               {
                  "key": "inside%1:15:00::"
               },
               {
                  "key": "inside%1:15:01::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "posisinya di dalam atau dekat dengan pusat",
            "enwordnet": [
               {
                  "key": "inner%3:00:00::"
               },
               {
                  "key": "inside%3:00:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "yang tidak tampak dari luar",
            "enwordnet": {
               "sense": {
                  "key": "internal%3:00:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "jauh ke bawah (dari permukaan); jauh masuk ke tengah (dari tepi)",
            "enwordnet": {
               "sense": {
                  "key": "deep%3:00:01::"
               }
            }
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "sampai ke lubuk hati; betul-betul terasakan di hati (tentang cinta, dendam, penderitaan, sakit hati",
            "enwordnet": {
               "sense": {
                  "key": "deep%3:00:00:intense:00"
               }
            }
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "paham benar-benar (tentang ilmu pengetahuan dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "deep%3:00:00:profound:00"
               }
            }
         },
         {
            "sid": "7",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai benda nyata yang mengandung isi, memuat sesuatu"
         },
         {
            "sid": "8",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai sesuatu abstrak yang dianggap mengandung isi"
         },
         {
            "sid": "9",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai kejadian, peristiwa, aktivitas yang melibatkan atau mengikutsertakan orang, benda, hal"
         },
         {
            "sid": "10",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai waktu dalam jangka tertentu"
         },
         {
            "sid": "11",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai tujuan, terkait hal yang ingin dicapai"
         },
         {
            "sid": "12",
            "pos": "preposition",
            "gloss": "kata depan untuk menandai bentuk, format, satuan atau ukuran"
         }
      ]
   },
   {
      "wid": "41",
      "text": "ketat",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "sempit (pakaian)",
            "enwordnet": {
               "sense": {
                  "key": "tight%3:00:01::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "tetap tidak dapat diubah, tanpa kecuali (tentang perkataan, janji, perintah, peraturan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "tight%3:00:00:demanding:01"
               },
               {
                  "key": "rigorous%3:00:00:demanding:01"
               },
               {
                  "key": "stringent%3:00:00:demanding:01"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "teliti, cermat, dan rapi (tentang penjagaan)",
            "enwordnet": [
               {
                  "key": "strict%3:00:00::"
               },
               {
                  "key": "rigorous%3:00:00:exact:00"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "sama kuat, alot (tentang pertandingan, kompetisi, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "close%3:00:00:equal:00"
               },
               {
                  "key": "tight%3:00:00:equal:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "42",
      "text": "kunci",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "alat yang terbuat dari logam, yang mana mekanisme penguncian dijalankan ketika dimasukkan ke induk kunci (untuk mengancing pintu, peti, dan sebagainya; menjalankan mesin; membuka sekrup)",
            "enwordnet": {
               "sense": {
                  "key": "key%1:06:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "jawaban yang disediakan atas pertanyaan ujian dan sebagainya",
            "enwordnet": {
               "sense": {
                  "key": "key%1:10:03::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "alat untuk mencapai suatu maksud (seperti membongkar rahasia, memecahkan masalah, menentukan kalah menang, atau berhasil tidaknya sesuatu)",
            "enwordnet": {
               "sense": {
                  "key": "key%1:09:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "runtunan nada yang berhubungan satu dan lainnya (berdasar pada suatu nada utama); lambang yang digunakan untuk menunjukkan letak not tertentu pada balok not",
            "enwordnet": [
               {
                  "key": "key%1:10:00::"
               },
               {
                  "key": "chord%1:10:00::"
               },
               {
                  "key": "tonality%1:10:00::"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "verb",
            "gloss": "perintah untuk mengunci pintu, jendela, dan sebagainya",
            "enwordnet": {
               "sense": {
                  "key": "lock%2:35:00::"
               }
            }
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "penting, sentral",
            "enwordnet": [
               {
                  "key": "key%3:10:00:important:00"
               },
               {
                  "key": "central%3:10:00:important:00"
               },
               {
                  "key": "fundamental%3:10:00:important:00"
               },
               {
                  "key": "cardinal%3:10:00:important:00"
               }
            ]
         },
         {
            "sid": "7",
            "pos": "noun",
            "gloss": "alat atau mekanisme (abstrak) apapun yang dapat memberikan akses (misalnya password, dsb)",
            "enwordnet": {
               "sense": {
                  "key": "key%1:10:01::"
               }
            }
         }
      ]
   },
   {
      "wid": "43",
      "text": "tengah",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "tempat (arah, titik) di antara dua tepi (batas); daerah yang bukan pinggiran; pusat",
            "enwordnet": [
               {
                  "key": "center%1:15:01::"
               },
               {
                  "key": "centre%1:15:01::"
               },
               {
                  "key": "middle%1:15:00::"
               },
               {
                  "key": "heart%1:15:00::"
               },
               {
                  "key": "eye%1:15:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "sela-sela; antara (orang banyak, kumpulan, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "midst%1:15:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "paruh; perdua; waktu di antara permulaan dan akhir suatu periode",
            "enwordnet": [
               {
                  "key": "half%1:23:00::"
               },
               {
                  "key": "middle%1:28:00::"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "adverb",
            "gloss": "sedang"
         }
      ]
   },
   {
      "wid": "44",
      "text": "atas",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bagian yang lebih tinggi",
            "enwordnet": [
               {
                  "key": "top%1:15:01"
               },
               {
                  "key": "top%1:15:02"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "permukaan, bagian paling atas",
            "enwordnet": [
               {
                  "key": "top%1:15:00"
               },
               {
                  "key": "upside%1:15:00"
               },
               {
                  "key": "upper_side%1:15:00"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "posisinya di atas permukaan (bagian paling atas) benda atau tempat lainnya, posisi tidak menempel"
         },
         {
            "sid": "4",
            "pos": "noun",
            "gloss": "lebih, melebihi"
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "berada pada posisi paling tinggi",
            "enwordnet": [
               {
                  "key": "top%3:00:00::"
               },
               {
                  "key": "upper%3:00:00:high:01"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "preposition",
            "gloss": "kata depan yang menandai sesuatu yang dikenai peristiwa, aktivitas (terhadap; terkait)"
         },
         {
            "sid": "7",
            "pos": "preposition",
            "gloss": "kata depan yang menandai sesuatu yang menjadi penyerta, penyebab, hal yang melatarbelakangi (disebabkan oleh; karena)"
         },
         {
            "sid": "8",
            "pos": "preposition",
            "gloss": "dari; menjadi (misalnya terdiri atas, dsb)"
         }
      ]
   },
   {
      "wid": "45",
      "text": "dasar",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "alas; bagian terbawah; lapisan terbawah",
            "enwordnet": [
               {
                  "key": "bottom%1:15:00::"
               },
               {
                  "key": "base%1:17:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "fondasi; pokok; basis",
            "enwordnet": [
               {
                  "key": "basis%1:09:00"
               },
               {
                  "key": "foundation%1:09:00"
               },
               {
                  "key": "base%1:09:00"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "berada pada posisi dasar, terendah, paling bawah",
            "enwordnet": {
               "sense": {
                  "key": "bottom%3:00:00::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "berfungsi sebagai dasar",
            "enwordnet": [
               {
                  "key": "base%3:00:00:basic:00"
               },
               {
                  "key": "basic%3:00:00::"
               }
            ]
         }
      ]
   },
   {
      "wid": "46",
      "text": "rapat",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "pertemuan (kumpulan) untuk membicarakan sesuatu; sidang; majelis",
            "enwordnet": {
               "sense": {
                  "key": "meeting%1:14:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "hampir tidak berantara; dekat sekali (tidak renggang); berhampiran; dekat sekali",
            "enwordnet": {
               "sense": {
                  "key": "tight%3:00:00:compact:00"
               }
            }
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "tertutup benar-benar hingga tidak bercelah",
            "enwordnet": {
               "sense": {
                  "key": "tight%3:00:00:invulnerable:00"
               }
            }
         }
      ]
   },
   {
      "wid": "47",
      "text": "coklat",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "makanan, minuman, atau produk olahan bubuk coklat",
            "enwordnet": {
               "sense": {
                  "key": "chocolate%1:13:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "tanaman kakao (pohon, buah, atau biji)",
            "enwordnet": {
               "sense": {
                  "key": "cacao%1:20:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "warna merah kehitam-hitaman seperti sawo matang",
            "enwordnet": {
               "sense": {
                  "key": "brown%3:00:00::"
               }
            }
         }
      ]
   },
   {
      "wid": "48",
      "text": "cerah",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "terang, memancarkan cahaya (tentang hari, bulan, warna)",
            "enwordnet": [
               {
                  "key": "bright%3:00:00::"
               },
               {
                  "key": "bright%3:00:00:colorful:00"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "berseri, bahagia (tentang muka)",
            "enwordnet": {
               "synonym": {
                  "text": "bright%3:00:00:happy:00"
               }
            }
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "menjanjikan, lebih baik di masa mendatang",
            "enwordnet": [
               {
                  "key": "bright%3:00:00:auspicious:00"
               },
               {
                  "key": "hopeful%3:00:00:auspicious:00"
               },
               {
                  "key": "promising%3:00:00:auspicious:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "49",
      "text": "panas",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "kalor; rasa seperti berada di dekat api",
            "enwordnet": {
               "sense": {
                  "key": "heat%1:19:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "demam; suhu tubuh lebih tinggi dari biasanya",
            "enwordnet": {
               "sense": {
                  "key": "fever%1:26:00"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "musim",
            "enwordnet": {
               "sense": {
                  "key": "summer%1:28:00"
               }
            }
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "terasa seperti terbakar atau berada di dekat api",
            "enwordnet": {
               "sense": {
                  "key": "hot%3:00:01"
               }
            }
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "genting; tegang; tidak menyenangkan (terkait perasaan, situasi, aktivitas, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "hot%3:00:00:violent:00"
               },
               {
                  "key": "hot%3:00:00:unpleasant:00"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "erotis, seksi",
            "enwordnet": {
               "sense": {
                  "key": "hot%3:00:00:sexy:00"
               }
            }
         }
      ]
   },
   {
      "wid": "50",
      "text": "cabang",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "satuan usaha, lembaga, perkumpulan, kantor, dan sebagainya yang merupakan bagian dari satuan yang lebih besar",
            "enwordnet": [
               {
                  "text": "branch%1:14:00::"
               },
               {
                  "text": "subdivision%1:14:01::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "noun",
            "gloss": "bagian batang kayu yang tumbuh dari pokok atau dahan (cabang yang besar disebut dahan dan cabang yang kecil disebut ranting)",
            "enwordnet": {
               "sense": {
                  "key": "branch%1:20:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "noun",
            "gloss": "bagian yang terpecah atau terbelah dari pokoknya (sungai, jalan, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "text": "branch%1:17:01::"
               }
            }
         }
      ]
   },
   {
      "wid": "51",
      "text": "tinggi",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "ketinggian; ukuran, dimensi vertikal",
            "enword": [
               {
                  "key": "height%1:07:00::"
               },
               {
                  "key": "tallness%1:07:00::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "jangkung, panjang (tentang badan, bangunan, dsb)",
            "enword": {
               "sense": {
                  "key": "tall%3:00:00::"
               }
            }
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "jauh jaraknya dari posisi sebelah bawah; sudah agak jauh ke atas",
            "enword": {
               "sense": {
                  "key": "high%3:00:01::"
               }
            }
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "luhur; mulia",
            "enword": [
               {
                  "key": "high%3:00:00:elated:00"
               },
               {
                  "key": "elevated%3:00:00:noble:01"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "berada di atas; posisinya lebih dari yang lain (tentang tingkatan, pangkat, derajat, mutu, dan sebagainya)",
            "enword": [
               {
                  "key": "high%3:00:00:superior:01"
               },
               {
                  "key": "eminent%3:00:00:superior:01"
               }
            ]
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "kuantitas atau intensitas lebih dari rata-rata; banyak (tentang harga, nilai), sudah lanjut (tentang umur)",
            "enword": {
               "sense": {
                  "key": "high%3:00:02::"
               }
            }
         },
         {
            "sid": "7",
            "pos": "adjective",
            "gloss": "sudah maju (tentang kecerdasan, peradaban, pengetahuan, dan sebagainya)",
            "enword": [
               {
                  "key": "advanced%3:00:02:high:02"
               },
               {
                  "key": "advanced%3:00:00:high-tech:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "52",
      "text": "berat",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "bobot; timbangan; besarnya tekanan suatu benda apabila diangkat, ditimbang, dan sebagainya",
            "enwordnet": {
               "sense": {
                  "key": "weight%1:07:00::"
               }
            }
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "besar bobotnya; besar ukuran timbangannya",
            "enwordnet": [
               {
                  "key": "heavy%3:00:01::"
               },
               {
                  "key": "weighty%3:00:00::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "serius; parah (tentang luka penyakit dan sebagainya)",
            "enwordnet": [
               {
                  "key": "severe%3:00:00:intense:00"
               },
               {
                  "key": "terrible%3:00:00:intense:00"
               },
               {
                  "key": "wicked%3:00:00:intense:00"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "sulit (susah, sukar) melakukannya; melebihi ukuran (kekuatan, kemampuan, kesanggupan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "rugged%3:00:00:difficult:00"
               },
               {
                  "key": "tough%3:00:01:difficult:00"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "sukar digerakkan (tentang anggota badan dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "heavy%3:00:01:effortful:00"
               }
            }
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "kuantitasnya besar untuk ukuran selain bobot (terkait kadar, intensitas, dsb)"
         }
      ]
   },
   {
      "wid": "53",
      "text": "asing",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "aneh; tidak biasa",
            "enwordnet": [
               {
                  "key": "strange%3:00:00::"
               },
               {
                  "key": "unusual%3:00:02::"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "datang dari luar (negeri, daerah, lingkungan)",
            "enwordnet": [
               {
                  "key": "foreign%3:00:01::"
               },
               {
                  "key": "strange%3:00:01::"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "tersendiri; terpisah sendiri; terpencil",
            "enwordnet": [
               {
                  "key": "alone%3:00:00:unaccompanied:00"
               },
               {
                  "key": "lone%3:00:00:unaccompanied:00"
               },
               {
                  "key": "lonely%3:00:00:unaccompanied:00"
               },
               {
                  "key": "solitary%3:00:00:unaccompanied:00"
               }
            ]
         }
      ]
   },
   {
      "wid": "54",
      "text": "besar",
      "senses": [
         {
            "sid": "1",
            "pos": "noun",
            "gloss": "besaran"
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "lebih dari ukuran sedang; lawan dari kecil",
            "enwordnet": [
               {
                  "key": "large%3:00:00"
               },
               {
                  "key": "big%3:00:01"
               }
            ]
         },
         {
            "sid": "3",
            "pos": "adjective",
            "gloss": "banyak; tidak sedikit (tentang jumlah, nominal)",
            "enwordnet": [
               {
                  "key": "huge%3:00:01:large:00"
               },
               {
                  "key": "immense%3:00:01:large:00"
               },
               {
                  "key": "vast%3:00:00:large:00"
               }
            ]
         },
         {
            "sid": "4",
            "pos": "adjective",
            "gloss": "hebat; mulia; berkuasa",
            "enwordnet": [
               {
                  "key": "big%3:00:00:conspicuous:00"
               },
               {
                  "key": "large%3:00:00:conspicuous:00"
               },
               {
                  "key": "prominent%3:00:02:conspicuous:00"
               }
            ]
         },
         {
            "sid": "5",
            "pos": "adjective",
            "gloss": "penting (berguna)",
            "enwordnet": {
               "sense": {
                  "key": "big%3:00:00:important:00"
               }
            }
         },
         {
            "sid": "6",
            "pos": "adjective",
            "gloss": "menjadi dewasa; lebih dewasa daripada sebelumnya",
            "enwordnet": [
               {
                  "key": "adult%3:00:00:mature:01"
               },
               {
                  "key": "big%3:00:00:mature:01"
               },
               {
                  "key": "grown%3:00:00:mature:01"
               }
            ]
         }
      ]
   },
   {
      "wid": "55",
      "text": "lebat",
      "senses": [
         {
            "sid": "1",
            "pos": "adjective",
            "gloss": "banyak, tebal, dan rapat (tentang rambut, daun, buah, hutan, dan sebagainya)",
            "enwordnet": [
               {
                  "key": "dense%3:00:00:impenetrable:00"
               },
               {
                  "key": "thick%3:00:00:impenetrable:00"
               }
            ]
         },
         {
            "sid": "2",
            "pos": "adjective",
            "gloss": "deras dan banyak (tentang hujan, embun, dan sebagainya)",
            "enwordnet": {
               "sense": {
                  "key": "heavy%3:00:03::"
               }
            }
         }
      ]
   }
]

# %%
def create_sense_id(wid, sid):
    wid = wid if len(wid) > 1 else f'0{wid}'
    sid = sid if len(sid) > 1 else f'0{sid}'
    return f'{wid}{sid}'

pos_map = {
    'adjective': 'JJ',
    'noun': 'NN',
    'preposition': 'IN',
    'verb': 'VB',
    'adverb': 'RB'
}

pos = {create_sense_id(word['wid'], sense['sid']): pos_map[sense['pos']] for word in a for sense in word['senses']}

# %%
pos
# Out:
# {'0101': 'VB',
#  '0102': 'NN',
#  '0103': 'VB',
#  '0201': 'NN',
#  '0202': 'NN',
#  '0203': 'NN',
#  '0204': 'NN',
#  '0301': 'NN',
#  '0302': 'NN',
#  '0303': 'NN',
#  '0304': 'NN',
#  '0401': 'NN',
#  '0402': 'NN',
#  '0403': 'NN',
#  '0501': 'NN',
#  '0502': 'NN',
#  '0503': 'NN',
#  '0601': 'NN',
#  '0602': 'NN',
#  '0603': 'NN',
#  '0701': 'NN',
#  '0702': 'NN',
#  '0703': 'NN',
#  '0801': 'NN',
#  '0802': 'NN',
#  '0803': 'NN',
#  '0804': 'NN',
#  '0901': 'NN',
#  '0902': 'NN',
#  '0903': 'NN',
#  '0904': 'NN',
#  '1001': 'NN',
#  '1002': 'NN',
#  '1003': 'NN',
#  '1004': 'NN',
#  '1005': 'NN',
#  '1006': 'NN',
#  '1101': 'NN',
#  '1102': 'NN',
#  '1103': 'NN',
#  '1104': 'NN',
#  '1201': 'NN',
#  '1202': 'NN',
#  '1301': 'NN',
#  '1302': 'NN',
#  '1303': 'NN',
#  '1304': 'NN',
#  '1401': 'NN',
#  '1402': 'NN',
#  '1403': 'NN',
#  '1501': 'NN',
#  '1502': 'NN',
#  '1503': 'NN',
#  '1504': 'NN',
#  '1601': 'NN',
#  '1602': 'NN',
#  '1701': 'NN',
#  '1702': 'NN',
# ...
